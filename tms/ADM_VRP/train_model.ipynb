# %%
import tensorflow as tf
from time import gmtime, strftime

from attention_dynamic_model import AttentionDynamicModel, set_decode_type
from reinforce_baseline import RolloutBaseline
from train import train_model

from utils import create_data_on_disk, get_cur_time

# Params of model
SAMPLES = 512 # 128*10000
BATCH = 128
START_EPOCH = 0
END_EPOCH = 5
FROM_CHECKPOINT = False
embedding_dim = 128
LEARNING_RATE = 0.0001
ROLLOUT_SAMPLES = 10000
NUMBER_OF_WP_EPOCHS = 1
GRAD_NORM_CLIPPING = 1.0
BATCH_VERBOSE = 1000
VAL_BATCH_SIZE = 1000
VALIDATE_SET_SIZE = 10000
SEED = 1234
GRAPH_SIZE = 50
FILENAME = 'VRP_{}_{}'.format(GRAPH_SIZE, strftime("%Y-%m-%d", gmtime()))

# Initialize model
model_tf = AttentionDynamicModel(embedding_dim)
set_decode_type(model_tf, "sampling")
print(get_cur_time(), 'model initialized')

# Create and save validation dataset
validation_dataset = create_data_on_disk(GRAPH_SIZE,
                                         VALIDATE_SET_SIZE,
                                         is_save=True,
                                         filename=FILENAME,
                                         is_return=True,
                                         seed = SEED)
print(get_cur_time(), 'validation dataset created and saved on the disk')

# Initialize optimizer
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# Initialize baseline
baseline = RolloutBaseline(model_tf,
                           wp_n_epochs = NUMBER_OF_WP_EPOCHS,
                           epoch = 0,
                           num_samples=ROLLOUT_SAMPLES,
                           filename = FILENAME,
                           from_checkpoint = FROM_CHECKPOINT,
                           embedding_dim=embedding_dim,
                           graph_size=GRAPH_SIZE
                           )
print(get_cur_time(), 'baseline initialized')

train_model(optimizer,
            model_tf,
            baseline,
            validation_dataset,
            samples = SAMPLES,
            batch = BATCH,
            val_batch_size = VAL_BATCH_SIZE,
            start_epoch = START_EPOCH,
            end_epoch = END_EPOCH,
            from_checkpoint = FROM_CHECKPOINT,
            grad_norm_clipping = GRAD_NORM_CLIPPING,
            batch_verbose = BATCH_VERBOSE,
            graph_size = GRAPH_SIZE,
            filename = FILENAME
            )
# Out:
# 2023-07-13 11:32:18 model initialized
# 2023-07-13 11:32:53 validation dataset created and saved on the disk
# Evaluating baseline model on baseline dataset (epoch = 0)
# Rollout greedy execution:   0%|          | 0/10 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 46
#      43 optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)
#      45 # Initialize baseline
# ---> 46 baseline = RolloutBaseline(model_tf,
#      47                            wp_n_epochs = NUMBER_OF_WP_EPOCHS,
#      48                            epoch = 0,
#      49                            num_samples=ROLLOUT_SAMPLES,
#      50                            filename = FILENAME,
#      51                            from_checkpoint = FROM_CHECKPOINT,
#      52                            embedding_dim=embedding_dim,
#      53                            graph_size=GRAPH_SIZE
#      54                            )
#      55 print(get_cur_time(), 'baseline initialized')
#      57 train_model(optimizer,
#      58             model_tf,
#      59             baseline,
#    (...)
#      70             filename = FILENAME
#      71             )
#
# File D:\bc\algorithm\tms\ADM_VRP\reinforce_baseline.py:103, in RolloutBaseline.__init__(self, model, filename, from_checkpoint, path_to_checkpoint, wp_n_epochs, epoch, num_samples, warmup_exp_beta, embedding_dim, graph_size)
#     100 self.graph_size = graph_size
#     102 # create and evaluate initial baseline
# --> 103 self._update_baseline(model, epoch)
#
# File D:\bc\algorithm\tms\ADM_VRP\reinforce_baseline.py:125, in RolloutBaseline._update_baseline(self, model, epoch)
#     122 self.dataset = generate_data_onfly(num_samples=self.num_samples, graph_size=self.graph_size)
#     124 print(f"Evaluating baseline model on baseline dataset (epoch = {epoch})")
# --> 125 self.bl_vals = rollout(self.model, self.dataset)
#     126 self.mean = tf.reduce_mean(self.bl_vals)
#     127 self.cur_epoch = epoch
#
# File D:\bc\algorithm\tms\ADM_VRP\reinforce_baseline.py:42, in rollout(model, dataset, batch_size, disable_tqdm)
#      39 costs_list = []
#      41 for batch in tqdm(dataset.batch(batch_size), disable=disable_tqdm, desc="Rollout greedy execution"):
# ---> 42     cost, _ = model(batch)
#      43     costs_list.append(cost)
#      45 return tf.concat(costs_list, axis=0)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\engine\training.py:558, in Model.__call__(self, *args, **kwargs)
#     554         super().__call__(inputs, *copied_args, **copied_kwargs)
#     556     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 558 return super().__call__(*args, **kwargs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File D:\bc\algorithm\tms\ADM_VRP\attention_dynamic_model.py:244, in AttentionDynamicModel.call(self, inputs, return_pi)
#     242     state.i = tf.zeros(1, dtype=tf.int64)
#     243     att_mask, cur_num_nodes = state.get_att_mask()
# --> 244     embeddings, context_vectors = self.embedder(inputs, att_mask, cur_num_nodes)
#     245     K_tanh, Q_context, K, V = self.get_projections(embeddings, context_vectors)
#     247 inner_i = 0
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File D:\bc\algorithm\tms\ADM_VRP\attention_graph_encoder.py:90, in GraphAttentionEncoder.call(self, x, mask, cur_num_nodes)
#      88 # stack attention layers
#      89 for i in range(self.num_layers):
# ---> 90     x = self.mha_layers[i](x, mask)
#      92 if mask is not None:
#      93     output = (x, tf.reduce_sum(x, axis=1) / cur_num_nodes)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File D:\bc\algorithm\tms\ADM_VRP\attention_graph_encoder.py:31, in MultiHeadAttentionLayer.call(self, x, mask)
#      30 def call(self, x, mask=None):
# ---> 31     mha_out = self.mha(x, x, x, mask)
#      32     sc1_out = tf.keras.layers.Add()([x, mha_out])
#      33     tanh1_out = tf.keras.activations.tanh(sc1_out)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\engine\base_layer.py:1145, in Layer.__call__(self, *args, **kwargs)
#    1140     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1142 with autocast_variable.enable_auto_cast_variables(
#    1143     self._compute_dtype_object
#    1144 ):
# -> 1145     outputs = call_fn(inputs, *args, **kwargs)
#    1147 if self._activity_regularizer:
#    1148     self._handle_activity_regularization(inputs, outputs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File D:\bc\algorithm\tms\ADM_VRP\layers.py:62, in MultiHeadAttention.call(self, q, k, v, mask)
#      60 # split heads: d_model = num_heads * head_depth + reshape
#      61 Q = self.split_heads(Q, batch_size)  # (batch_size, num_heads, seq_len_q, head_depth)
# ---> 62 K = self.split_heads(K, batch_size)  # (batch_size, num_heads, seq_len_k, head_depth)
#      63 V = self.split_heads(V, batch_size)  # (batch_size, num_heads, seq_len_v, head_depth)
#      65 # similarity between context vector Q and key K // self-similarity in case of self-attention
#
# File D:\bc\algorithm\tms\ADM_VRP\layers.py:48, in MultiHeadAttention.split_heads(self, tensor, batch_size)
#      43 """Function for computing attention on several heads simultaneously 同时计算多个头部注意力的功能
#      44 Splits last dimension of a tensor into (num_heads, head_depth).
#      45 Then we transpose it as (batch_size, num_heads, ..., head_depth) so that we can use broadcast
#      46 """
#      47 tensor = tf.reshape(tensor, (batch_size, -1, self.n_heads, self.head_depth))
# ---> 48 return tf.transpose(tensor, perm=[0, 2, 1, 3])
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\ops\array_ops.py:2301, in transpose_v2(a, perm, conjugate, name)
#    2223 @tf_export("transpose", v1=[])
#    2224 @dispatch.add_dispatch_support
#    2225 def transpose_v2(a, perm=None, conjugate=False, name="transpose"):
#    2226   """Transposes `a`, where `a` is a Tensor.
#    2227
#    2228   Permutes the dimensions according to the value of `perm`.
#    (...)
#    2299     A transposed `Tensor`.
#    2300   """
# -> 2301   return transpose(a=a, perm=perm, name=name, conjugate=conjugate)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\ops\array_ops.py:2382, in transpose(a, perm, name, conjugate)
#    2379   transpose_fn = gen_array_ops.transpose
#    2381 if perm is not None:
# -> 2382   return transpose_fn(a, perm, name=name)
#    2384 rank = a.shape.rank
#    2385 if rank is None:
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:14944, in transpose(x, perm, name)
#   14942   pass
#   14943 try:
# > 14944   return transpose_eager_fallback(
#   14945       x, perm, name=name, ctx=_ctx)
#   14946 except _core._SymbolicException:
#   14947   pass  # Add nodes to the TensorFlow graph.
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:14969, in transpose_eager_fallback(x, perm, name, ctx)
#   14967 _inputs_flat = [x, perm]
#   14968 _attrs = ("T", _attr_T, "Tperm", _attr_Tperm)
# > 14969 _result = _execute.execute(b"Transpose", 1, inputs=_inputs_flat,
#   14970                            attrs=_attrs, ctx=ctx, name=name)
#   14971 if _execute.must_record_gradient():
#   14972   _execute.record_gradient(
#   14973       "Transpose", _inputs_flat, _attrs, _result)
#
# File C:\Program Files\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
from time import gmtime, strftime

from attention_dynamic_model import set_decode_type
from reinforce_baseline import RolloutBaseline
from train import train_model

from utils import get_cur_time
from reinforce_baseline import load_tf_model
from utils import read_from_pickle


SAMPLES = 512 # 128*10000
BATCH = 128
LEARNING_RATE = 0.0001
ROLLOUT_SAMPLES = 10000
NUMBER_OF_WP_EPOCHS = 1
GRAD_NORM_CLIPPING = 1.0
BATCH_VERBOSE = 1000
VAL_BATCH_SIZE = 1000
VALIDATE_SET_SIZE = 10000
SEED = 1234
GRAPH_SIZE = 50
FILENAME = 'VRP_{}_{}'.format(GRAPH_SIZE, strftime("%Y-%m-%d", gmtime()))

START_EPOCH = 5
END_EPOCH = 10
FROM_CHECKPOINT = True
embedding_dim = 128
MODEL_PATH = 'model_checkpoint_epoch_4_VRP_50_2020-06-08.h5'
VAL_SET_PATH = 'Validation_dataset_VRP_50_2020-06-08.pkl'
BASELINE_MODEL_PATH = 'baseline_checkpoint_epoch_0_VRP_50_2020-06-08.h5'

# Initialize model
model_tf = load_tf_model(MODEL_PATH,
                         embedding_dim=embedding_dim,
                         graph_size=GRAPH_SIZE)
set_decode_type(model_tf, "sampling")
print(get_cur_time(), 'model loaded')

# Create and save validation dataset
validation_dataset = read_from_pickle(VAL_SET_PATH)
print(get_cur_time(), 'validation dataset loaded')

# Initialize optimizer
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# Initialize baseline
baseline = RolloutBaseline(model_tf,
                           wp_n_epochs = NUMBER_OF_WP_EPOCHS,
                           epoch = START_EPOCH,
                           num_samples=ROLLOUT_SAMPLES,
                           filename = FILENAME,
                           from_checkpoint = FROM_CHECKPOINT,
                           embedding_dim=embedding_dim,
                           graph_size=GRAPH_SIZE,
                           path_to_checkpoint = BASELINE_MODEL_PATH)
print(get_cur_time(), 'baseline initialized')

train_model(optimizer,
            model_tf,
            baseline,
            validation_dataset,
            samples = SAMPLES,
            batch = BATCH,
            val_batch_size = VAL_BATCH_SIZE,
            start_epoch = START_EPOCH,
            end_epoch = END_EPOCH,
            from_checkpoint = FROM_CHECKPOINT,
            grad_norm_clipping = GRAD_NORM_CLIPPING,
            batch_verbose = BATCH_VERBOSE,
            graph_size = GRAPH_SIZE,
            filename = FILENAME
            )
